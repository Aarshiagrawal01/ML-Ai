# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images.jpg')
img2 = cv2.imread('download.jpg')
img = img[70:70+225,70:70+225,:]

# %%
img.shape , img2.shape
# Out:
# ((225, 225, 3), (225, 225, 3))

# %%
def showing(im):
    plt.imshow(im[:,:,::-1])
    plt.show()

def imshow(im):
    cv2.imshow('Preview' ,im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
imshow(img)
imshow(img2)

# %%
showing(img)

# %%
showing(img2)

# %%
added = cv2.add(img , img2)
showing(added)

# %%
sub = cv2.subtract(img , img2)
showing(sub)

# %%
img2_2= cv2.convertScaleAbs(img2 , alpha=1.3 , beta=50)
showing(img2)

# %%
img2_3 =cv2.resize(img2 , (400,400) , interpolation=cv2.INTER_CUBIC)
img2_3.shape
# Out:
# (400, 400, 3)

# %%
img2_4=cv2.resize(img2 ,None,fx=2 , fy=0.5, interpolation=cv2.INTER_CUBIC)
showing(img2_4)

# %%
img2_5=cv2.resize(img2 ,None,fx=2 , fy=0.5, interpolation=cv2.INTER_CUBIC)
showing(img2_4)

# %%
from skimage.transform import rotate
image_rotate=rotate(img2,angle=700,resize=True)
showing(image_rotate)

# %%
img2_5 = rotate(img2,angle = - 45,resize=True)
showing(img2_5)

# %%
from time import sleep 
while True:
    for i in range(360):
        i = rotate(img,angle=i,resize=True)
        cv2.imshow('',i)
        key = cv2.waitKey(1)
        if key == ord('x'):
            repeat = False
            break
        sleep(0.1)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/apple/Documents/vs code/ ML-Ai/new5may.ipynb Cell 17' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/apple/Documents/vs%20code/%20ML-Ai/new5may.ipynb#ch0000016?line=7'>8</a>     repeat = False
#       <a href='vscode-notebook-cell:/Users/apple/Documents/vs%20code/%20ML-Ai/new5may.ipynb#ch0000016?line=8'>9</a>     break
# ---> <a href='vscode-notebook-cell:/Users/apple/Documents/vs%20code/%20ML-Ai/new5may.ipynb#ch0000016?line=9'>10</a> sleep(0.1)
#
# KeyboardInterrupt:

# %%
BGR

img-RGB
img_gray - Gray

Red Plane - img[:,:,2]
Green Plane - img[:,:,1]
Blue Plane - img[:,:,0]
# Out:
#   Input In [22]
#     Red Plane - img[:,:,2]
#         ^
# SyntaxError: invalid syntax

# %%
im_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
im_r = img[:,:,2].copy()
im_g = img[:,:,1].copy()
im_b = img[:,:,0].copy()

# %%
plt.subplot(1,5,1)
plt.imshow(img[:,:,::-1])

plt.subplot(1,5,2)
plt.imshow(im_gray, cmap='gray')

ply.subplot
